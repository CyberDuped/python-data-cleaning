# %% [markdown]
# # Understanding the Data

# %%
import pandas as pd
import numpy as np
import os

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\rondu\\Desktop\\Dev1\\python-data-cleaning\\notebooks'

# %%
fight_air = pd.read_csv(r"..\data\fighter_aircraft_dataset_v7.csv")
fight_air.head()
# Out:
#              Aircraft     Manufacturer Country Generation             Role  \
# 0        F-22A Raptor  Lockheed Martin     USA          5  Air Superiority
# 1  F-35A Lightning II  Lockheed Martin     USA          5        Multirole
# 2         Su-57 Felon           Sukhoi  Russia          5        Multirole
# 3         F-15C Eagle           Boeing     USA          4  Air Superiority
# 4     F-15EX Eagle II           Boeing     USA        4.5        Multirole
#
#    First_Flight  In_Service  Max_Speed_kmh  Supercruise_kmh  \
# 0          1997        2005           2130             1810
# 1          2006        2016           1960                0
# 2          2010        2020           2135             1400
# 3          1972        1976           2655                0
# 4          2021        2024           2655                0
#
#    Service_Ceiling_m  ...  EW_Score  Combat_Kills  Combat_Losses_AirToAir  \
# 0              15000  ...      0.95             0                       0
# ...

# %%
fight_air.tail()
# Out:
#              Aircraft Manufacturer           Country Generation       Role  \
# 29  F/A-18F Block III       Boeing               USA        4.5  Multirole
# 30           Su-30SM2       Sukhoi            Russia        4++  Multirole
# 31          Rafale F4     Dassault            France        4.5  Multirole
# 32             J-10CE      Chengdu             China        4.5  Multirole
# 33             F-15SA       Boeing  USA/Saudi Arabia        4.5  Multirole
#
#     First_Flight  In_Service  Max_Speed_kmh  Supercruise_kmh  \
# 29          2020        2022           1915                0
# 30          2020        2022           2120                0
# 31          2023        2024           1912                0
# 32          2020        2022           2200                0
# 33          2013        2017           2655                0
#
#     Service_Ceiling_m  ...  EW_Score  Combat_Kills  Combat_Losses_AirToAir  \
# ...

# %%
fight_air.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Aircraft                      34 non-null     str
#  1   Manufacturer                  34 non-null     str
#  2   Country                       34 non-null     str
#  3   Generation                    34 non-null     str
#  4   Role                          34 non-null     str
#  5   First_Flight                  34 non-null     int64
#  6   In_Service                    34 non-null     int64
#  7   Max_Speed_kmh                 34 non-null     int64
#  8   Supercruise_kmh               34 non-null     int64
#  9   Service_Ceiling_m             34 non-null     int64
#  10  Combat_Radius_km              34 non-null     int64
#  11  Ferry_Range_km                34 non-null     int64
#  12  Empty_Weight_kg               34 non-null     int64
# ...

# %%
fight_air.describe
# Out:
# <bound method NDFrame.describe of                  Aircraft     Manufacturer           Country Generation  \
# 0            F-22A Raptor  Lockheed Martin               USA          5
# 1      F-35A Lightning II  Lockheed Martin               USA          5
# 2             Su-57 Felon           Sukhoi            Russia          5
# 3             F-15C Eagle           Boeing               USA          4
# 4         F-15EX Eagle II           Boeing               USA        4.5
# 5   F-16C Fighting Falcon  Lockheed Martin               USA          4
# 6    F/A-18E Super Hornet           Boeing               USA        4.5
# 7        Su-35S Flanker-E           Sukhoi            Russia        4++
# 8           Su-27 Flanker           Sukhoi            Russia          4
# 9          MiG-29 Fulcrum          Mikoyan            Russia          4
# 10        MiG-31 Foxhound          Mikoyan            Russia          4
# 11     J-20 Mighty Dragon          Chengdu             China          5
# ...

# %%
rows, cols = fight_air.shape
print(f'Rows: {rows}')
print(f'Cols: {cols}')
# Out:
# Rows: 34
# Cols: 45

# %%
fight_air.columns
# Out:
# Index(['Aircraft', 'Manufacturer', 'Country', 'Generation', 'Role',
#        'First_Flight', 'In_Service', 'Max_Speed_kmh', 'Supercruise_kmh',
#        'Service_Ceiling_m', 'Combat_Radius_km', 'Ferry_Range_km',
#        'Empty_Weight_kg', 'MTOW_kg', 'Hardpoints', 'Max_Weapon_Load_kg',
#        'Radar_Type', 'Radar_Model', 'RCS_m2', 'Engine_Count', 'Engine_Model',
#        'Thrust_per_Engine_kN', 'Supercruise_Capable', 'Thrust_Vectoring',
#        'Internal_Weapons_Bay', 'Units_Produced', 'Unit_Cost_M_USD', 'Status',
#        'Internal_Fuel_kg', 'Fuel_Consumption_Cruise_kg_h',
#        'Number_of_Operators', 'Cruise_Speed_kmh', 'Cost_per_Flight_Hour_USD',
#        'Radar_Score', 'Missile_Score', 'EW_Score', 'Combat_Kills',
#        'Combat_Losses_AirToAir', 'Combat_Record_Status', 'Kill_Loss_Ratio',
#        'Combat_Kills_A2A', 'Combat_Losses_A2A', 'Combat_Status', 'Kill_Ratio',
#        'Combat_Sorties_Estimated'],
#       dtype='str')
